# %%
"""用logistic regression分类预测病马的死亡率"""
import numpy as np
from numpy import *
import csv

"""定义sigmoid函数"""
def sigmoid(inX):
    return 1.0/(1+exp(-inX))

"""以回归系数和特征向量作为输入计算预测的类别"""
def classify(inX,weights):
    prediction = sigmoid(sum(inX * weights))
    if prediction>0.5:
        return 1.0
    else:
        return 0.0

"""1.梯度上升法  采用批处理方式更新回归系数值.批处理:一次处理所有数据,回归系数的更新需要遍历整个数据集"""
def StocGradAscent_improved_V1(dataMatrix,labelMatrix,numIter = 500):
    m,n = shape(dataMatrix)
    weights = ones(n)
    for j in range(numIter):
        dataIndex = list(range(m))
        for i in range(m):
            alpha = 4/(1.0+j+i) + 0.01   #动态更新alpha值,越来越小,但最小不会超过0.01
            randIndex = int(random.uniform(0,len(dataIndex)))
            prediction = sigmoid(sum(dataMatrix[randIndex] * weights))  #随机选取更新点,避免连续点引起的周期性抖动
            error = labelMatrix[randIndex] - prediction
            weights = weights + alpha * error * dataMatrix[randIndex]
            del(dataIndex[randIndex])
    return weights

"""对训练集和测试集进行处理"""
def dealdata():
    frtrain = open('/home/jerry/GitRepository/JupyterProjects/dataset/horseColicTraining.txt','r')
    frtest = open('/home/jerry/GitRepository/JupyterProjects/dataset/horseColicTest.txt','r')
    trainSet = []
    trainLabels = []
    """读取数据存到列表当中"""
    for line in frtrain.readlines():
        currLine = line.strip().split('\t')
        lineArr = []
        for i in range(21):  #csv文件总共有22列,前21列是数据,最后一列是标签
            lineArr.append(float(currLine[i]))  #读取切分好的元素添加到lineArr当中,append在添加单个元素时要加上变量类型
            
        trainSet.append(lineArr) #存储整个训练集数据
        trainLabels.append(float(currLine[21]))
    trainWeights = StocGradAscent_improved_V1(array(trainSet),trainLabels)  #计算训练集的梯度
    accCount = 0  #统计分类准确的个数
    numTest = 0 #统计纳入分类统计的总数
    """加载测试集,并对每一个加载的数据进行测试分类正确性"""
   
    for line1 in frtest.readlines():
        numTest = numTest + 1  #每次加载一行,计算参与分类数据+1
        currLine1 = line1.strip().split('\t')
        lineArr1 = []
        for i in range(21):
            lineArr1.append(float(currLine1[i]))
        if float(classify(lineArr1,trainWeights)) == float(currLine1[21]):  #判断加载的每一个数据分类是否准确
            accCount = accCount + 1
#     print('numTest:',numTest)
#     print('accCount:',accCount)

    accuracy = (float(accCount) / numTest)
    print('the accuracy is : %s' % accuracy)       
    frtrain.close()
    frtest.close()
    return accuracy 

"""多次测试"""
def multiTest():
    numTest = 20
    accSum = 0
    """进行numTest数量测试,计算所有准确率之和"""
    for k in range(numTest):
        accSum = accSum + dealdata()
    print('after %d iteration,the average accuracy is:%s' % (numTest,accSum/float(numTest)))   
    
# """绘制分类结果的决策边界"""
# def plotBestFit()
    
if __name__ == '__main__':
    multiTest()
# Out:
# the accuracy is : 0.6716417910447762
# the accuracy is : 0.6865671641791045
# the accuracy is : 0.582089552238806
# the accuracy is : 0.6417910447761194
# the accuracy is : 0.6119402985074627
# the accuracy is : 0.6268656716417911
# the accuracy is : 0.6417910447761194
# the accuracy is : 0.6119402985074627
# the accuracy is : 0.582089552238806
# the accuracy is : 0.4925373134328358
# the accuracy is : 0.6417910447761194
# the accuracy is : 0.6119402985074627
# the accuracy is : 0.6119402985074627
# the accuracy is : 0.6268656716417911
# the accuracy is : 0.6119402985074627
# the accuracy is : 0.6119402985074627
# the accuracy is : 0.5970149253731343
# the accuracy is : 0.6119402985074627
# the accuracy is : 0.6716417910447762
# the accuracy is : 0.6268656716417911
# after 20 iteration,the average accuracy is:0.6186567164179105
